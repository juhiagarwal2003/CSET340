# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
gray_image = cv2.imread('/content/sample_data/grayscale_example.jpg', cv2.IMREAD_GRAYSCALE)

color_image = cv2.imread('/content/sample_data/file_example_JPG_100kB.jpg')

# %%
gray_hist = cv2.calcHist([gray_image], [0], None, [256], [0, 256])

print("Grayscale Histogram Values:\n", gray_hist)
# Out:
# Grayscale Histogram Values:
#  [[0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [1.0000e+00]
#  [7.0000e+00]
#  [2.5000e+01]
#  [5.4000e+01]
#  [7.8000e+01]
#  [1.4100e+02]
#  [2.3500e+02]
#  [2.3000e+02]
#  [2.7100e+02]
#  [3.4600e+02]
#  [3.7400e+02]
#  [4.5900e+02]
#  [5.0900e+02]
#  [6.9200e+02]
#  [8.8800e+02]
#  [1.1110e+03]
#  [1.3360e+03]
#  [1.7760e+03]
#  [2.0150e+03]
#  [2.2840e+03]
#  [2.6530e+03]
#  [2.8930e+03]
#  [3.1170e+03]
#  [3.2290e+03]
#  [3.4040e+03]
#  [3.5810e+03]
#  [3.9640e+03]
#  [4.1340e+03]
#  [4.2880e+03]
#  [4.7540e+03]
#  [4.8200e+03]
#  [4.6330e+03]
#  [4.2500e+03]
#  [3.6040e+03]
#  [3.2840e+03]
#  [3.0880e+03]
#  [3.1450e+03]
#  [3.4990e+03]
#  [3.7470e+03]
#  [3.9670e+03]
#  [4.5200e+03]
#  [5.0880e+03]
#  [5.7530e+03]
#  [6.0950e+03]
#  [6.3550e+03]
#  [6.0290e+03]
#  [6.0410e+03]
#  [5.7900e+03]
#  [5.9870e+03]
#  [5.7980e+03]
#  [5.5220e+03]
#  [4.9930e+03]
#  [4.7250e+03]
#  [4.6770e+03]
#  [4.9540e+03]
#  [4.9920e+03]
#  [5.4620e+03]
#  [5.5690e+03]
#  [5.7460e+03]
#  [5.7180e+03]
#  [5.5320e+03]
#  [5.7580e+03]
#  [5.5520e+03]
#  [5.3620e+03]
#  [5.2310e+03]
#  [4.7480e+03]
#  [4.3050e+03]
#  [3.9480e+03]
#  [3.7200e+03]
#  [3.5590e+03]
#  [3.5940e+03]
#  [3.7290e+03]
#  [3.6700e+03]
#  [3.5820e+03]
#  [3.3390e+03]
#  [3.2870e+03]
#  [3.0080e+03]
#  [2.7020e+03]
#  [2.4870e+03]
#  [2.2110e+03]
#  [2.0860e+03]
#  [1.9300e+03]
#  [1.5560e+03]
#  [1.2070e+03]
#  [9.1300e+02]
#  [6.9900e+02]
#  [5.6100e+02]
#  [4.2500e+02]
#  [3.0100e+02]
#  [1.8800e+02]
#  [1.7600e+02]
#  [1.0900e+02]
#  [9.2000e+01]
#  [7.6000e+01]
#  [4.5000e+01]
#  [2.9000e+01]
#  [2.6000e+01]
#  [1.8000e+01]
#  [2.4000e+01]
#  [2.2000e+01]
#  [2.3000e+01]
#  [2.9000e+01]
#  [2.2000e+01]
#  [1.4000e+01]
#  [2.0000e+01]
#  [1.5000e+01]
#  [2.4000e+01]
#  [1.8000e+01]
#  [1.3000e+01]
#  [1.8000e+01]
#  [4.6000e+01]
#  [5.7000e+01]
#  [8.8000e+01]
#  [1.2400e+02]
#  [1.4200e+02]
#  [1.8000e+02]
#  [1.9900e+02]
#  [2.3900e+02]
#  [2.4200e+02]
#  [2.2100e+02]
#  [2.1600e+02]
#  [2.2100e+02]
#  [2.1100e+02]
#  [2.0800e+02]
#  [2.4400e+02]
#  [2.4800e+02]
#  [2.6400e+02]
#  [2.3700e+02]
#  [2.7400e+02]
#  [2.2800e+02]
#  [2.6800e+02]
#  [2.6600e+02]
#  [2.6200e+02]
#  [3.1400e+02]
#  [3.7600e+02]
#  [3.5400e+02]
#  [3.4600e+02]
#  [3.8300e+02]
#  [3.6000e+02]
#  [3.4900e+02]
#  [4.1700e+02]
#  [3.8300e+02]
#  [4.8200e+02]
#  [4.9300e+02]
#  [4.8100e+02]
#  [5.2100e+02]
#  [4.9900e+02]
#  [5.1100e+02]
#  [4.6700e+02]
#  [4.4000e+02]
#  [4.1500e+02]
#  [4.4000e+02]
#  [4.0000e+02]
#  [4.3600e+02]
#  [4.3400e+02]
#  [4.5800e+02]
#  [4.4700e+02]
#  [4.5000e+02]
#  [4.7800e+02]
#  [4.2900e+02]
#  [4.0500e+02]
#  [4.1100e+02]
#  [3.5800e+02]
#  [3.5700e+02]
#  [3.4000e+02]
#  [3.0700e+02]
#  [3.1000e+02]
#  [3.4400e+02]
#  [3.0800e+02]
#  [2.7800e+02]
#  [2.8200e+02]
#  [2.9700e+02]
#  [2.9400e+02]
#  [2.7900e+02]
#  [2.9200e+02]
#  [3.1100e+02]
#  [2.5300e+02]
#  [3.0400e+02]
#  [2.6600e+02]
#  [2.6400e+02]
#  [2.8900e+02]
#  [3.0000e+02]
#  [2.5500e+02]
#  [2.5800e+02]
#  [2.7800e+02]
#  [2.4300e+02]
#  [2.5300e+02]
#  [2.2800e+02]
#  [2.4600e+02]
#  [2.5800e+02]
#  [2.7500e+02]
#  [2.5700e+02]
#  [2.5900e+02]
#  [2.7700e+02]
#  [2.7500e+02]
#  [2.4100e+02]
#  [2.9300e+02]
#  [3.0400e+02]
#  [2.9900e+02]
#  [2.7300e+02]
#  [2.6500e+02]
#  [2.4100e+02]
#  [2.6500e+02]
#  [2.9200e+02]
#  [2.3900e+02]
#  [2.3000e+02]
#  [2.3600e+02]
#  [2.2300e+02]
#  [2.4900e+02]
#  [2.6100e+02]
#  [2.4700e+02]
#  [2.4600e+02]
#  [2.6000e+02]
#  [2.2400e+02]
#  [2.6600e+02]
#  [2.4600e+02]
#  [2.4500e+02]
#  [2.4000e+02]
#  [2.4000e+02]
#  [2.4800e+02]
#  [2.5800e+02]
#  [2.4000e+02]
#  [2.6400e+02]
#  [2.3200e+02]
#  [2.4300e+02]
#  [2.5500e+02]
#  [2.4100e+02]
#  [2.4100e+02]
#  [2.3600e+02]
#  [2.3400e+02]
#  [2.1800e+02]
#  [2.4000e+02]
#  [2.5100e+02]
#  [2.3800e+02]
#  [2.0600e+02]
#  [2.2600e+02]
#  [2.3800e+02]
#  [2.8000e+02]
#  [2.9500e+02]
#  [5.0400e+02]
#  [1.3480e+03]
#  [3.4937e+04]]

# %%
# Split color image into channels
b, g, r = cv2.split(color_image)

# Compute histograms for each channel
b_hist = cv2.calcHist([b], [0], None, [256], [0, 256])
g_hist = cv2.calcHist([g], [0], None, [256], [0, 256])
r_hist = cv2.calcHist([r], [0], None, [256], [0, 256])

# Display histogram values
print("Blue Channel Histogram Values:\n", b_hist)
print("Green Channel Histogram Values:\n", g_hist)
print("Red Channel Histogram Values:\n", r_hist)
# Out:
# Blue Channel Histogram Values:
#  [[1.3823e+04]
#  [1.4444e+04]
#  [1.4158e+04]
#  [8.9510e+03]
#  [4.7120e+03]
#  [2.6020e+03]
#  [1.7000e+03]
#  [1.2840e+03]
#  [1.1480e+03]
#  [9.9300e+02]
#  [9.5100e+02]
#  [9.9200e+02]
#  [1.0250e+03]
#  [1.0460e+03]
#  [1.0860e+03]
#  [1.1620e+03]
#  [1.1230e+03]
#  [1.0880e+03]
#  [1.1640e+03]
#  [1.1350e+03]
#  [1.1160e+03]
#  [1.0950e+03]
#  [1.0290e+03]
#  [1.0680e+03]
#  [1.0010e+03]
#  [9.1500e+02]
#  [9.3400e+02]
#  [8.3500e+02]
#  [8.7500e+02]
#  [8.5600e+02]
#  [7.8700e+02]
#  [7.7300e+02]
#  [7.7300e+02]
#  [7.3000e+02]
#  [7.0100e+02]
#  [8.9800e+02]
#  [1.0210e+03]
#  [1.2550e+03]
#  [1.3730e+03]
#  [1.4860e+03]
#  [1.2520e+03]
#  [1.2540e+03]
#  [1.3250e+03]
#  [1.2670e+03]
#  [1.1430e+03]
#  [1.2290e+03]
#  [1.2210e+03]
#  [1.2290e+03]
#  [1.0480e+03]
#  [1.0210e+03]
#  [1.0270e+03]
#  [9.9700e+02]
#  [1.0550e+03]
#  [1.0090e+03]
#  [1.1170e+03]
#  [1.1530e+03]
#  [1.2350e+03]
#  [1.1980e+03]
#  [1.2500e+03]
#  [1.4990e+03]
#  [1.6730e+03]
#  [2.1900e+03]
#  [2.4430e+03]
#  [2.7360e+03]
#  [2.7180e+03]
#  [2.8880e+03]
#  [2.9610e+03]
#  [3.4030e+03]
#  [3.6890e+03]
#  [3.8650e+03]
#  [4.2280e+03]
#  [3.9810e+03]
#  [3.4310e+03]
#  [3.1040e+03]
#  [2.9300e+03]
#  [2.6980e+03]
#  [2.6060e+03]
#  [2.5710e+03]
#  [2.6300e+03]
#  [2.4280e+03]
#  [2.4040e+03]
#  [2.6710e+03]
#  [2.6750e+03]
#  [2.8090e+03]
#  [2.6630e+03]
#  [2.7340e+03]
#  [2.9790e+03]
#  [2.9270e+03]
#  [2.9950e+03]
#  [2.8180e+03]
#  [2.7910e+03]
#  [2.9820e+03]
#  [3.3250e+03]
#  [3.3880e+03]
#  [3.5520e+03]
#  [3.5700e+03]
#  [3.5980e+03]
#  [3.8030e+03]
#  [4.2560e+03]
#  [5.4630e+03]
#  [7.4780e+03]
#  [8.3570e+03]
#  [9.1840e+03]
#  [8.8680e+03]
#  [7.3100e+03]
#  [7.1220e+03]
#  [6.6500e+03]
#  [5.8480e+03]
#  [5.1410e+03]
#  [5.1890e+03]
#  [4.7080e+03]
#  [4.5370e+03]
#  [4.6100e+03]
#  [4.6740e+03]
#  [4.7220e+03]
#  [4.7880e+03]
#  [4.8400e+03]
#  [4.7600e+03]
#  [4.8800e+03]
#  [4.6130e+03]
#  [4.4530e+03]
#  [4.3470e+03]
#  [4.1910e+03]
#  [4.0890e+03]
#  [4.0110e+03]
#  [3.9470e+03]
#  [4.1350e+03]
#  [3.6450e+03]
#  [3.0710e+03]
#  [2.7280e+03]
#  [2.6090e+03]
#  [2.4710e+03]
#  [2.2070e+03]
#  [1.9130e+03]
#  [1.9060e+03]
#  [1.8310e+03]
#  [1.8210e+03]
#  [1.8410e+03]
#  [1.8880e+03]
#  [1.8660e+03]
#  [1.8650e+03]
#  [1.8640e+03]
#  [1.8920e+03]
#  [2.1270e+03]
#  [2.1490e+03]
#  [2.5160e+03]
#  [2.3690e+03]
#  [2.5480e+03]
#  [2.8120e+03]
#  [2.5700e+03]
#  [3.2940e+03]
#  [3.6470e+03]
#  [3.8140e+03]
#  [5.4370e+03]
#  [6.4510e+03]
#  [6.7580e+03]
#  [6.1030e+03]
#  [5.4270e+03]
#  [7.1190e+03]
#  [8.4760e+03]
#  [9.3370e+03]
#  [9.9600e+03]
#  [1.0532e+04]
#  [7.0460e+03]
#  [7.4900e+03]
#  [7.5400e+03]
#  [1.1046e+04]
#  [9.6920e+03]
#  [7.6870e+03]
#  [1.0197e+04]
#  [7.6240e+03]
#  [1.2225e+04]
#  [1.1584e+04]
#  [4.4220e+03]
#  [3.2210e+03]
#  [2.3900e+03]
#  [2.3500e+03]
#  [2.5040e+03]
#  [2.3250e+03]
#  [2.2340e+03]
#  [2.0930e+03]
#  [2.6800e+03]
#  [2.6270e+03]
#  [2.0800e+03]
#  [2.4270e+03]
#  [3.2860e+03]
#  [2.7450e+03]
#  [2.9830e+03]
#  [1.7930e+03]
#  [3.1100e+03]
#  [2.3450e+03]
#  [2.0820e+03]
#  [3.0650e+03]
#  [1.5470e+03]
#  [2.4760e+03]
#  [3.1980e+03]
#  [2.1880e+03]
#  [3.0910e+03]
#  [1.5940e+03]
#  [1.3570e+03]
#  [3.4270e+03]
#  [1.3570e+03]
#  [2.8380e+03]
#  [1.9030e+03]
#  [1.7800e+03]
#  [2.6920e+03]
#  [1.7040e+03]
#  [1.7200e+03]
#  [1.5510e+03]
#  [1.4320e+03]
#  [1.6660e+03]
#  [1.0990e+03]
#  [1.7980e+03]
#  [1.6450e+03]
#  [1.4740e+03]
#  [1.2480e+03]
#  [8.9700e+02]
#  [1.0260e+03]
#  [1.2620e+03]
#  [9.4100e+02]
#  [7.2400e+02]
#  [8.6400e+02]
#  [7.9400e+02]
#  [5.3900e+02]
#  [5.8200e+02]
#  [1.1170e+03]
#  [1.3700e+03]
#  [7.7000e+02]
#  [5.1900e+02]
#  [1.4200e+03]
#  [1.1840e+03]
#  [1.0700e+03]
#  [4.6700e+02]
#  [2.7900e+02]
#  [2.8400e+02]
#  [2.1200e+02]
#  [2.3100e+02]
#  [2.0700e+02]
#  [1.1800e+02]
#  [1.3900e+02]
#  [1.1600e+02]
#  [8.4000e+01]
#  [1.8000e+01]
#  [6.5000e+01]
#  [4.8000e+01]
#  [1.9000e+01]
#  [7.8000e+01]
#  [2.8000e+01]
#  [9.8000e+01]
#  [2.1200e+02]
#  [9.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [0.0000e+00]
#  [1.0000e+00]
#  [1.0000e+00]]
# Green Channel Histogram Values:
#  [[ 1976.]
#  [ 2119.]
#  [ 1562.]
#  [ 1048.]
#  [  840.]
#  [  709.]
#  [  615.]
#  [  609.]
#  [  635.]
#  [  586.]
#  [  650.]
#  [  621.]
#  [  603.]
#  [  535.]
#  [  553.]
#  [  565.]
#  [  592.]
#  [  578.]
#  [  597.]
#  [  640.]
#  [  614.]
#  [  614.]
#  [  644.]
#  [  629.]
#  [  644.]
#  [  646.]
#  [  679.]
#  [  626.]
#  [  628.]
#  [  565.]
#  [  596.]
#  [  652.]
#  [  679.]
#  [  703.]
#  [  731.]
#  [  686.]
#  [  726.]
#  [  772.]
#  [  814.]
#  [  937.]
#  [  916.]
#  [  931.]
#  [  887.]
#  [  900.]
#  [  827.]
#  [  804.]
#  [  933.]
#  [  935.]
#  [  958.]
#  [ 1070.]
#  [ 1054.]
#  [ 1118.]
#  [ 1166.]
#  [ 1205.]
#  [ 1238.]
#  [ 1257.]
#  [ 1230.]
#  [ 1307.]
#  [ 1315.]
#  [ 1354.]
#  [ 1347.]
#  [ 1394.]
#  [ 1176.]
#  [ 1094.]
#  [ 1138.]
#  [ 1137.]
#  [ 1112.]
#  [ 1139.]
#  [ 1128.]
#  [ 1187.]
#  [ 1237.]
#  [ 1246.]
#  [ 1295.]
#  [ 1299.]
#  [ 1382.]
#  [ 1441.]
#  [ 1497.]
#  [ 1681.]
#  [ 1759.]
#  [ 1820.]
#  [ 1866.]
#  [ 1801.]
#  [ 1878.]
#  [ 1808.]
#  [ 1698.]
#  [ 1677.]
#  [ 1731.]
#  [ 1827.]
#  [ 1797.]
#  [ 1819.]
#  [ 1609.]
#  [ 1558.]
#  [ 1539.]
#  [ 1561.]
#  [ 1496.]
#  [ 1428.]
#  [ 1361.]
#  [ 1375.]
#  [ 1423.]
#  [ 1476.]
#  [ 1596.]
#  [ 1809.]
#  [ 1935.]
#  [ 1975.]
#  [ 2011.]
#  [ 2190.]
#  [ 2441.]
#  [ 1875.]
#  [ 1506.]
#  [ 1536.]
#  [ 1492.]
#  [ 1509.]
#  [ 1597.]
#  [ 1368.]
#  [ 1372.]
#  [ 1278.]
#  [ 1305.]
#  [ 1370.]
#  [ 1234.]
#  [ 1307.]
#  [ 1400.]
#  [ 1345.]
#  [ 1585.]
#  [ 1744.]
#  [ 2057.]
#  [ 2110.]
#  [ 2670.]
#  [ 3044.]
#  [ 3518.]
#  [ 3315.]
#  [ 3371.]
#  [ 3662.]
#  [ 4047.]
#  [ 3990.]
#  [ 3842.]
#  [ 3411.]
#  [ 3318.]
#  [ 2867.]
#  [ 2725.]
#  [ 2912.]
#  [ 2984.]
#  [ 2735.]
#  [ 2721.]
#  [ 2908.]
#  [ 2900.]
#  [ 2851.]
#  [ 2885.]
#  [ 2869.]
#  [ 3006.]
#  [ 3212.]
#  [ 3450.]
#  [ 3696.]
#  [ 3952.]
#  [ 3711.]
#  [ 3671.]
#  [ 3514.]
#  [ 3426.]
#  [ 3455.]
#  [ 3565.]
#  [ 3436.]
#  [ 3796.]
#  [ 3436.]
#  [ 3329.]
#  [ 3085.]
#  [ 3111.]
#  [ 3176.]
#  [ 3671.]
#  [ 4153.]
#  [ 4280.]
#  [ 4731.]
#  [ 4614.]
#  [ 4164.]
#  [ 4373.]
#  [ 4532.]
#  [ 4567.]
#  [ 4104.]
#  [ 3755.]
#  [ 3435.]
#  [ 3578.]
#  [ 3540.]
#  [ 3415.]
#  [ 3429.]
#  [ 3417.]
#  [ 3695.]
#  [ 3549.]
#  [ 3989.]
#  [ 4021.]
#  [ 4533.]
#  [ 4377.]
#  [ 4355.]
#  [ 4411.]
#  [ 4156.]
#  [ 3926.]
#  [ 4079.]
#  [ 4486.]
#  [ 4594.]
#  [ 4257.]
#  [ 3454.]
#  [ 3532.]
#  [ 3346.]
#  [ 2814.]
#  [ 2515.]
#  [ 2472.]
#  [ 2309.]
#  [ 2648.]
#  [ 2889.]
#  [ 2976.]
#  [ 3429.]
#  [ 3314.]
#  [ 3772.]
#  [ 5456.]
#  [10120.]
#  [13199.]
#  [12414.]
#  [18795.]
#  [26569.]
#  [24688.]
#  [ 9674.]
#  [ 6515.]
#  [ 4653.]
#  [ 5362.]
#  [ 4386.]
#  [ 6190.]
#  [ 5207.]
#  [ 3526.]
#  [ 3694.]
#  [ 3733.]
#  [ 4109.]
#  [ 4149.]
#  [ 4436.]
#  [ 4504.]
#  [ 4633.]
#  [ 4276.]
#  [ 3991.]
#  [ 4122.]
#  [ 6094.]
#  [ 6977.]
#  [ 8352.]
#  [ 8396.]
#  [ 7578.]
#  [ 8316.]
#  [ 7337.]
#  [ 8774.]
#  [ 5872.]
#  [ 4335.]
#  [ 3140.]
#  [ 2206.]
#  [ 1330.]
#  [ 1170.]
#  [  854.]
#  [  747.]
#  [  624.]
#  [  791.]
#  [  887.]
#  [ 1258.]
#  [  526.]]
# Red Channel Histogram Values:
#  [[   821.]
#  [   641.]
#  [   608.]
#  [   366.]
#  [   216.]
#  [   494.]
#  [   293.]
#  [   368.]
#  [   144.]
#  [   201.]
#  [   270.]
#  [   316.]
#  [   350.]
#  [   313.]
#  [   268.]
#  [   168.]
#  [   236.]
#  [   261.]
#  [   317.]
#  [   354.]
#  [   232.]
#  [   228.]
#  [   266.]
#  [   304.]
#  [   329.]
#  [   372.]
#  [   305.]
#  [   302.]
#  [   276.]
#  [   247.]
#  [   195.]
#  [   221.]
#  [   253.]
#  [   271.]
#  [   308.]
#  [   287.]
#  [   334.]
#  [   270.]
#  [   300.]
#  [   288.]
#  [   323.]
#  [   343.]
#  [   360.]
#  [   355.]
#  [   389.]
#  [   389.]
#  [   393.]
#  [   368.]
#  [   338.]
#  [   329.]
#  [   311.]
#  [   345.]
#  [   370.]
#  [   381.]
#  [   333.]
#  [   366.]
#  [   380.]
#  [   380.]
#  [   419.]
#  [   417.]
#  [   398.]
#  [   426.]
#  [   428.]
#  [   454.]
#  [   418.]
#  [   407.]
#  [   445.]
#  [   398.]
#  [   433.]
#  [   398.]
#  [   419.]
#  [   436.]
#  [   490.]
#  [   447.]
#  [   459.]
#  [   418.]
#  [   444.]
#  [   421.]
#  [   476.]
#  [   465.]
#  [   493.]
#  [   551.]
#  [   501.]
#  [   511.]
#  [   503.]
#  [   532.]
#  [   521.]
#  [   557.]
#  [   540.]
#  [   510.]
#  [   569.]
#  [   632.]
#  [   661.]
#  [   756.]
#  [   676.]
#  [   626.]
#  [   740.]
#  [   816.]
#  [   788.]
#  [   867.]
#  [   837.]
#  [   980.]
#  [   930.]
#  [   922.]
#  [   949.]
#  [   889.]
#  [   859.]
#  [   931.]
#  [   993.]
#  [   956.]
#  [   901.]
#  [  1019.]
#  [  1119.]
#  [  1093.]
#  [  1093.]
#  [  1230.]
#  [  1208.]
#  [  1158.]
#  [  1200.]
#  [  1176.]
#  [  1190.]
#  [  1148.]
#  [  1233.]
#  [  1295.]
#  [  1329.]
#  [  1375.]
#  [  1324.]
#  [  1366.]
#  [  1411.]
#  [  1503.]
#  [  1405.]
#  [  1376.]
#  [  1515.]
#  [  1536.]
#  [  1494.]
#  [  1435.]
#  [  1425.]
#  [  1431.]
#  [  1476.]
#  [  1426.]
#  [  1485.]
#  [  1460.]
#  [  1494.]
#  [  1482.]
#  [  1500.]
#  [  1421.]
#  [  1525.]
#  [  1630.]
#  [  1731.]
#  [  1715.]
#  [  1760.]
#  [  1884.]
#  [  2093.]
#  [  1964.]
#  [  1916.]
#  [  1838.]
#  [  1768.]
#  [  1891.]
#  [  1793.]
#  [  1733.]
#  [  1786.]
#  [  1848.]
#  [  1831.]
#  [  1744.]
#  [  1666.]
#  [  1741.]
#  [  1815.]
#  [  1715.]
#  [  1940.]
#  [  2080.]
#  [  2189.]
#  [  2222.]
#  [  2404.]
#  [  2784.]
#  [  3194.]
#  [  3329.]
#  [  3306.]
#  [  3520.]
#  [  3995.]
#  [  4182.]
#  [  4916.]
#  [  5378.]
#  [  5803.]
#  [  5782.]
#  [  6215.]
#  [  6229.]
#  [  6188.]
#  [  5962.]
#  [  5240.]
#  [  4514.]
#  [  3730.]
#  [  2991.]
#  [  3201.]
#  [  3209.]
#  [  3077.]
#  [  2722.]
#  [  2707.]
#  [  2905.]
#  [  2854.]
#  [  3125.]
#  [  3169.]
#  [  3706.]
#  [  4121.]
#  [  4007.]
#  [  4367.]
#  [  4837.]
#  [  5369.]
#  [  6077.]
#  [  6791.]
#  [  6834.]
#  [  6186.]
#  [  6563.]
#  [  6851.]
#  [  5960.]
#  [  6082.]
#  [  6444.]
#  [  7888.]
#  [  7880.]
#  [  7427.]
#  [  6586.]
#  [  4940.]
#  [  4216.]
#  [  3892.]
#  [  4973.]
#  [  3606.]
#  [  2758.]
#  [  3145.]
#  [  6050.]
#  [  4962.]
#  [  5903.]
#  [  4011.]
#  [  4010.]
#  [  6951.]
#  [  5608.]
#  [  4895.]
#  [  3958.]
#  [  4701.]
#  [  6342.]
#  [  7583.]
#  [  7520.]
#  [  6589.]
#  [  7827.]
#  [  6089.]
#  [  5058.]
#  [  3810.]
#  [  4394.]
#  [  5009.]
#  [  5140.]
#  [  5313.]
#  [  3853.]
#  [  3648.]
#  [  4675.]
#  [  7867.]
#  [ 17271.]
#  [ 54733.]
#  [117385.]]

# %%
# For grayscale image
plt.figure()
plt.title("Grayscale Histogram (Pixel Count)")
plt.xlabel("Intensity Value")
plt.ylabel("Pixel Count")
plt.plot(gray_hist)
plt.xlim([0, 256])
plt.show()

# For color image
plt.figure()
plt.title("Color Histogram (Pixel Count)")
plt.xlabel("Intensity Value")
plt.ylabel("Pixel Count")
plt.plot(b_hist, color='blue')
plt.plot(g_hist, color='green')
plt.plot(r_hist, color='red')
plt.xlim([0, 256])
plt.show()

# %%
bright_image = cv2.imread('/content/sample_data/snowy-mountain-gray-custom.jpg', cv2.IMREAD_GRAYSCALE)
dark_image = cv2.imread('/content/sample_data/Darkb&w.jpg', cv2.IMREAD_GRAYSCALE)

bright_hist = cv2.calcHist([bright_image], [0], None, [256], [0, 256])
dark_hist = cv2.calcHist([dark_image], [0], None, [256], [0, 256])

plt.figure()
plt.title("Bright vs Dark Image Histograms")
plt.xlabel("Intensity Value")
plt.ylabel("Pixel Count")
plt.plot(bright_hist, color='blue', label='Bright Image')
plt.plot(dark_hist, color='red', label='Dark Image')
plt.legend()
plt.xlim([0, 256])
plt.show()

# %%
equalized_image = cv2.equalizeHist(gray_image)

equalized_hist = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(gray_image, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("Equalized Image")
plt.imshow(equalized_image, cmap='gray')
plt.show()

plt.figure()
plt.title("Original vs Equalized Histogram")
plt.xlabel("Intensity Value")
plt.ylabel("Pixel Count")
plt.plot(gray_hist, color='blue', label='Original')
plt.plot(equalized_hist, color='red', label='Equalized')
plt.legend()
plt.xlim([0, 256])
plt.show()

# %%
b, g, r = cv2.split(color_image)

b_equalized = cv2.equalizeHist(b)
g_equalized = cv2.equalizeHist(g)
r_equalized = cv2.equalizeHist(r)

equalized_color_image = cv2.merge([b_equalized, g_equalized, r_equalized])

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Color Image")
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))

plt.subplot(1, 2, 2)
plt.title("Equalized Color Image")
plt.imshow(cv2.cvtColor(equalized_color_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Part 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
gray_image = cv2.imread('/content/sample_data/grayscale_example.jpg', cv2.IMREAD_GRAYSCALE)

plt.figure()
plt.title("Original Grayscale Image")
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
dft = np.fft.fft2(gray_image)

dft_shifted = np.fft.fftshift(dft)

magnitude_spectrum = np.log(np.abs(dft_shifted) + 1)

# %%
plt.figure()
plt.title("Magnitude Spectrum (Log Scale)")
plt.imshow(magnitude_spectrum, cmap='gray')
plt.axis('off')
plt.show()

# %%
idft_shifted = np.fft.ifftshift(dft_shifted)

reconstructed_image = np.fft.ifft2(idft_shifted)

reconstructed_image = np.abs(reconstructed_image)

# %%
plt.figure()
plt.title("Reconstructed Image")
plt.imshow(reconstructed_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
(h, w) = gray_image.shape

rotation_matrix = cv2.getRotationMatrix2D((w // 2, h // 2), 45, 1.0)

rotated_image = cv2.warpAffine(gray_image, rotation_matrix, (w, h))

plt.figure()
plt.title("Rotated Image (45 Degrees)")
plt.imshow(rotated_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
dft_rotated = np.fft.fft2(rotated_image)

dft_rotated_shifted = np.fft.fftshift(dft_rotated)

magnitude_spectrum_rotated = np.log(np.abs(dft_rotated_shifted) + 1)

# %%
plt.figure()
plt.title("Magnitude Spectrum of Rotated Image (Log Scale)")
plt.imshow(magnitude_spectrum_rotated, cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Original Magnitude Spectrum")
plt.imshow(magnitude_spectrum, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Rotated Magnitude Spectrum")
plt.imshow(magnitude_spectrum_rotated, cmap='gray')
plt.axis('off')

plt.show()
